# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 24 15:07:28 2022

@author: ttack
"""
import os
import cv2
import matplotlib.pyplot as plt
#%% Tiff 설정
import cupy as np
import torch
import torch.nn as nn
from PIL import Image
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms

from mcplexpt.caber.CNN import CNNclass
from mcplexpt.caber.dos import DoSCaBERExperiment
from mcplexpt.caber.PCA import pcaclass
from mcplexpt.testing import get_samples_path

cv2.cuda.setDevice(0)
path = get_samples_path("caber", "dos", "sample_250fps.tiff")
expt1 = DoSCaBERExperiment(path)
expt2 = DoSCaBERExperiment(path)
expt3 = DoSCaBERExperiment(path)
pca1 = pcaclass()
CNN1 = CNNclass()


#%% 분석 명령어
"""엑셀파일만들기,원본파일,파일명"""

"""expt1.Image_Radius_Measure_temp('/home/minhyukim/samples/caber/dos/230117_slurry_ref_1000.tif','230117_ref',1000)"""
"""expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_002_3.tif','220516_PEO206_10_CAR014_002_3',10000)
expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_003_1.tif','220516_PEO206_10_CAR014_003_1',10000)
expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_003_2.tif','220516_PEO206_10_CAR014_003_2',10000)"""

#CNN1.foward_regression('/home/minhyukim/CNN/Concentration_regression','/home/minhyukim/CNN/Results')
# CNN1.foward_classfication('/home/minhyukim/CNN/Concentration_regression','/home/minhyukim/CNN/Results')

"""expt1.powerlawplot('230117_ref.xlsx')"""
"""expt1.powerlawfitting('230117_CMC0p6 (2).xlsx',0.5,0.45,0.5,0.5)
expt1.powerlawfitting('230117_CMC1 (1).xlsx',0.5,5.1,0.5,0.5)
expt1.powerlawfitting('230117_ref.xlsx',0.5,1.9,0.5,0.5)"""


"""
expt1.Extensional_viscosity_total('220516_PEO206_10_CAR014_002_2 (2).xlsx',64.28)
expt2.Extensional_viscosity_total('220516_PEO206_10_CAR014_003_1.xlsx',64.28)
expt3.Extensional_viscosity_total('220516_PEO206_10_CAR014_003(onetime)_1.xlsx',64.28)
"""

"""엑셀파일로 분석"""

"""expt1.Dos_CaBER_VE_analysis('221116_slurry1.xlsx',250000,200)"""
"""expt1.Dos_CaBER_VE_analysis('220526_Carbopol_002_PEO_01_00.xlsx',2000,10000)"""
"""expt1.Dos_CaBER_VE_analysis('220526_Carbopol_003_PEO_01_001.xlsx',4000,10000)"""


"""expt2.Dos_CaBER_VE_analysis('220516_PEO206_10_CAR014_003_1.xlsx',64.28)
expt3.Dos_CaBER_VE_analysis('220516_PEO206_10_CAR014_003(onetime)_1.xlsx',64.28)
"""
"""Extensional_viscosity"""
"""expt1.Radiusplotting('230117_CMC0p6 (1).xlsx')"""

"""Relaxation time"""
"""expt1.relaxationtime('Thinning0.xlsx','Total0.xlsx')"""

#expt1.Image_storage('220826_jun_Carbopol(014)',30)


#expt1.Image_storage('220314_CMC(10)_',30)
#expt1.Image_storage('220609_CMC_01',30)
#expt1.Image_storage('220720_CMC(10)_',30)

#expt1.Image_storage('220609_CMC,Carbo_11_',30)
#expt1.Image_storage('220826_CMC1_CARBOPOL1',30)


#expt1.Image_storage('230126_PEO1_CMC1_Carbopol3',30)


#expt1.Image_storage('220525_Carbo5PEO5_2skip_',30)

'''
expt1.Image_storage('220609_CMC,Carbo_11_',50)
expt1.Image_storage('220826_CMC1_CARBOPOL1',50)

expt1.Image_storage('220608_PEO,CMC,Carbo_111_',50)

expt1.Image_storage('220608_PEO,CMC_11_',50)


expt1.Image_storage('220826_jun_Carbopol(014)',50)
expt1.Image_storage('220829_Carbopol(014)_',50)

expt1.Image_storage('220314_CMC(10)_',50)
expt1.Image_storage('220609_CMC_01',50)
expt1.Image_storage('220720_CMC(10)_',50)



expt1.Image_storage('220405_PEO200_10',50)


expt1.Image_storage('220525_Carbo5PEO5_2skip_',50)
expt1.Image_storage('220609_PEO,Carbo_11_',50)

expt1.Image_storage('220608_PEO,CMC,Carbo_111_',50)

'''



#pca1.eigen7('1','2','3','4','5','6','7',0,1,2,1,1)
#pca1.eigen7('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',0,1,2,1,1,25,30)
#pca1.eigen7('230508_Carbopol_100weight_30frame_1','230509_CMC_100_weight_30frame_1','230509_PEO_100weight_30frame_1','230509_CMC1_Carbopol1_100weight_30frame_1','230508_PEO1_Carbopol1_100weight_30frame_1','230509_PEO1_CMC1_100weight_30frame_1','230509_PEO1_CMC1_Carbopol1_100weight_30frame_1',0,1,2,1,1,25,30)
#pca1.eigen7('230413_Carbopol_100weight','230411_CMC_100weight','230411_PEO_100weight','230412_CMC1_Carbopol1_100weight','230412_PEO1,Carbopol1_100weight','230412_PEO1,CMC1_100weight','230412_PEO1,CMC1,Carbopol1_100weight',0,1,2,1,1)
#pca1.eigen7('230410_Carbopol_weight','230411_CMC_weight','230411_PEO_weight','230412_CMC1_Carbopol1_weight','230412_PEO1,Carbopol1_weight','230412_PEO1,CMC1_weight','230412_PEO1,CMC1,Carbopol1_weight',0,1,2,1,1)
#pca1.eigen7('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',0,1,2,1,1)
#pca1.eigen7('230508_Carbopol_100weight_50frame','230509_CMC_100_weight_50frame','230509_PEO_100weight_50frame','230509_CMC1_Carbopol1_100weight_50frame','230508_PEO1_Carbopol1_100weight_50frame','230509_PEO1_CMC1_100weight_50frame','230509_PEO1_CMC1_Carbopol1_100weight_50frame',0,1,2,1,1,25,50)
#pca1.eigen7('230508_Carbopol_100weight_50frame_1','230509_CMC_100_weight_50frame_1','230509_PEO_100weight_50frame_1','230509_CMC1_Carbopol1_100weight_50frame_1','230508_PEO1_Carbopol1_100weight_50frame_1','230509_PEO1_CMC1_100weight_50frame_1','230509_PEO1_CMC1_Carbopol1_100weight_50frame_1',0,1,2,1,1,25,50)
#pca1.eigen7('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight')
#pca1.augmentation('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',3)
#pca1.augmentation('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',30)
#pca1.augmentation('230620_Carbopol_10frame_50weight','230620_CMC_10frame_50weight','230620_PEO_10frame_50weight','230620_Carbopol1_CMC1_10frame_50weight','230620_Carbopol1_PEO1_10frame_50weight','230620_PEO1_CMC1_10frame_50weight','230620_Carbopol1_CMC1_PEO1_10frame_50weight',30)
#pca1.component('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',30)
#pca1.box_Plot0(55)
#pca1.box_Plot1(55)


#pca1.accuracy_Plot('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',50)
#pca1.scatter_Plot(12)
#pca1.box_Plot2(30)
#pca1.ratio_Plot('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',0,1,2,1,1,5,50,7)
#pca1.ratio_Plot('230621_Carbopol_10frame_150weight','230621_CMC_10frame_150weight','230621_PEO_10frame_150weight','230621_Carbopol1_CMC1_10frame_150weight','230621_Carbopol1_PEO1_10frame_150weight','230621_PEO1_CMC1_10frame_150weight','230621_Carbopol1_CMC1_PEO1_10frame_150weight',0,1,2,1,1,25,50,6)
#pca1.ratio_Plot('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',0,1,2,1,1,25,50,10)
#pca1.ratio_Plot('230508_Carbopol_100weight_50frame','230509_CMC_100_weight_50frame','230509_PEO_100weight_50frame','230509_CMC1_Carbopol1_100weight_50frame','230508_PEO1_Carbopol1_100weight_50frame','230509_PEO1_CMC1_100weight_50frame','230509_PEO1_CMC1_Carbopol1_100weight_50frame',0,1,2,1,1,20,50,10)
#pca1.ratio_Plot('230413_Carbopol_100weight','230411_CMC_100weight','230411_PEO_100weight','230412_CMC1_Carbopol1_100weight','230412_PEO1,Carbopol1_100weight','230412_PEO1,CMC1_100weight','230412_PEO1,CMC1,Carbopol1_100weight',0,1,2,1,1,25,50,26)

#pca1.ratio_Plot('220907_Carbopol_noweight_1','220907_CMC_noweight_1','220907_PEO_noweight_1','220907_CMC1,Carbopol1_noweight_1','220907_PEO1,Carbopol1_noweight_1','220907_PEO1,CMC1_noweight_1','220907_PEO1,CMC1,Carbopol1_noweight_1',0,1,2,1,1,25,10,7)
pca1.ratio_Plot('230413_Carbopol_100weight_1','230411_CMC_100weight_1','230411_PEO_100weight_1','230412_CMC1_Carbopol1_100weight_1','230412_PEO1,Carbopol1_100weight_1','230412_PEO1,CMC1_100weight_1','230412_PEO1,CMC1,Carbopol1_100weight_1',0,1,2,1,1,35,50,26)
#pca1.ratio_Plot('230508_Carbopol_100weight_30frame_1','230509_CMC_100_weight_30frame_1','230509_PEO_100weight_30frame_1','230509_CMC1_Carbopol1_100weight_30frame_1','230508_PEO1_Carbopol1_100weight_30frame_1','230509_PEO1_CMC1_100weight_30frame_1','230509_PEO1_CMC1_Carbopol1_100weight_30frame_1',0,1,2,1,1,25,50,29)
#pca1.ratio_Plot('230508_Carbopol_100weight_50frame_1','230509_CMC_100_weight_50frame_1','230509_PEO_100weight_50frame_1','230509_CMC1_Carbopol1_100weight_50frame_1','230508_PEO1_Carbopol1_100weight_50frame_1','230509_PEO1_CMC1_100weight_50frame_1','230509_PEO1_CMC1_Carbopol1_100weight_50frame_1',0,1,2,1,1,20,50,29)
# Out:
# images.shape: (280, 360, 400)
# 클래스의 개수: 7

# %%
b=11/114*100
print(b)
# Out:
# 9.649122807017543

# %%
c=8/85*100
print(c)
# Out:
# 9.411764705882353

# %%
d=11/209*100
print(d)
# Out:
# 5.263157894736842

# %%
e=8/209*100
print(e)
# Out:
# 3.827751196172249

# %%
import matplotlib.pyplot as plt
from mcplexpt.caber.PCA import pcaclass
import numpy as np

pca1=pcaclass()

component=pca1.component('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',30)
scorespc1=component[8][:,0]
scorespc2=component[8][:,1]
scoreaveragepc1=component[1]
label=component[7]

fig1,ax1=plt.subplots(figsize=(5,3),dpi=200)
xticks=['CLASS1','CLASS2','CLASS3','CLASS4','CLASS5','CLASS6','CLASS7']
loss=[5.01,0.34,0.51,0.3,7.7,0.55,0.81]

ax1.plot(xticks,loss,color=(0.7,0.1,0.1,0.7))
ax1.set_xticks(xticks,xticks,fontsize=10)
ax1.set_yticks(range(0,9),range(0,9),fontsize=10)
ax1.set_title('Loss Modulus G˝',fontsize=20)


fig2,ax2=plt.subplots(figsize=(5,3),dpi=200)

extv=[19,1.8,64,0.74,16.6,48,31.4]

ax2.plot(xticks,extv,color=(0.7,0.1,0.1,0.7))
ax2.set_xticks(xticks,xticks,fontsize=10)
ax2.set_yticks(range(0,64,10),range(0,64,10),fontsize=10)
ax2.set_title('Extension viscosity',fontsize=20)

fig3,ax3=plt.subplots(figsize=(5,3),dpi=200)

loss=[5.01,0.34,0.51,0.3,7.7,0.55,0.81]

ax3.plot(xticks,scoreaveragepc1[0],color=(0.7,0.1,0.1,0.7))
ax3.set_xticks(xticks,xticks,fontsize=10)
#ax3.set_yticks(range(0,9),range(0,9),fontsize=10)
ax3.set_title('PC1 Score',fontsize=20)

fig4,ax4=plt.subplots(figsize=(5,3),dpi=200)
ax4.plot(xticks,scoreaveragepc1[1],color=(0.7,0.1,0.1,0.7))
ax4.set_xticks(xticks,xticks,fontsize=10)
#ax3.set_yticks(range(0,9),range(0,9),fontsize=10)
ax4.set_title('PC2 Score',fontsize=20)
# Out:
# images.shape: (209, 360, 400)
# 클래스의 개수: 7
# Text(0.5, 1.0, 'PC2 Score')

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 24 15:07:28 2022

@author: ttack
"""
import os
import cv2
import matplotlib.pyplot as plt
#%% Tiff 설정
import cupy as np
import torch
import torch.nn as nn
from PIL import Image
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms

from mcplexpt.caber.CNN import CNNclass
from mcplexpt.caber.dos import DoSCaBERExperiment
from mcplexpt.caber.PCA import pcaclass
from mcplexpt.testing import get_samples_path

cv2.cuda.setDevice(0)
path = get_samples_path("caber", "dos", "sample_250fps.tiff")
expt1 = DoSCaBERExperiment(path)
expt2 = DoSCaBERExperiment(path)
expt3 = DoSCaBERExperiment(path)
pca1 = pcaclass()
CNN1 = CNNclass()


#%% 분석 명령어
"""엑셀파일만들기,원본파일,파일명"""

"""expt1.Image_Radius_Measure_temp('/home/minhyukim/samples/caber/dos/230117_slurry_ref_1000.tif','230117_ref',1000)"""
"""expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_002_3.tif','220516_PEO206_10_CAR014_002_3',10000)
expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_003_1.tif','220516_PEO206_10_CAR014_003_1',10000)
expt1.Image_Radius_Measure('/home/minhyukim/samples/caber/dos/220516_PEO206_10_CAR014_003_2.tif','220516_PEO206_10_CAR014_003_2',10000)"""

#CNN1.foward_regression('/home/minhyukim/CNN/Concentration_regression','/home/minhyukim/CNN/Results')
# CNN1.foward_classfication('/home/minhyukim/CNN/Concentration_regression','/home/minhyukim/CNN/Results')

"""expt1.powerlawplot('230117_ref.xlsx')"""
"""expt1.powerlawfitting('230117_CMC0p6 (2).xlsx',0.5,0.45,0.5,0.5)
expt1.powerlawfitting('230117_CMC1 (1).xlsx',0.5,5.1,0.5,0.5)
expt1.powerlawfitting('230117_ref.xlsx',0.5,1.9,0.5,0.5)"""


"""
expt1.Extensional_viscosity_total('220516_PEO206_10_CAR014_002_2 (2).xlsx',64.28)
expt2.Extensional_viscosity_total('220516_PEO206_10_CAR014_003_1.xlsx',64.28)
expt3.Extensional_viscosity_total('220516_PEO206_10_CAR014_003(onetime)_1.xlsx',64.28)
"""

"""엑셀파일로 분석"""

"""expt1.Dos_CaBER_VE_analysis('221116_slurry1.xlsx',250000,200)"""
"""expt1.Dos_CaBER_VE_analysis('220526_Carbopol_002_PEO_01_00.xlsx',2000,10000)"""
"""expt1.Dos_CaBER_VE_analysis('220526_Carbopol_003_PEO_01_001.xlsx',4000,10000)"""


"""expt2.Dos_CaBER_VE_analysis('220516_PEO206_10_CAR014_003_1.xlsx',64.28)
expt3.Dos_CaBER_VE_analysis('220516_PEO206_10_CAR014_003(onetime)_1.xlsx',64.28)
"""
"""Extensional_viscosity"""
"""expt1.Radiusplotting('230117_CMC0p6 (1).xlsx')"""

"""Relaxation time"""
"""expt1.relaxationtime('Thinning0.xlsx','Total0.xlsx')"""

#expt1.Image_storage('220826_jun_Carbopol(014)',30)


#expt1.Image_storage('220314_CMC(10)_',30)
#expt1.Image_storage('220609_CMC_01',30)
#expt1.Image_storage('220720_CMC(10)_',30)

#expt1.Image_storage('220609_CMC,Carbo_11_',30)
#expt1.Image_storage('220826_CMC1_CARBOPOL1',30)


#expt1.Image_storage('230126_PEO1_CMC1_Carbopol3',30)


#expt1.Image_storage('220525_Carbo5PEO5_2skip_',30)

'''
expt1.Image_storage('220609_CMC,Carbo_11_',50)
expt1.Image_storage('220826_CMC1_CARBOPOL1',50)

expt1.Image_storage('220608_PEO,CMC,Carbo_111_',50)

expt1.Image_storage('220608_PEO,CMC_11_',50)


expt1.Image_storage('220826_jun_Carbopol(014)',50)
expt1.Image_storage('220829_Carbopol(014)_',50)

expt1.Image_storage('220314_CMC(10)_',50)
expt1.Image_storage('220609_CMC_01',50)
expt1.Image_storage('220720_CMC(10)_',50)



expt1.Image_storage('220405_PEO200_10',50)


expt1.Image_storage('220525_Carbo5PEO5_2skip_',50)
expt1.Image_storage('220609_PEO,Carbo_11_',50)

expt1.Image_storage('220608_PEO,CMC,Carbo_111_',50)

'''



#pca1.eigen7('1','2','3','4','5','6','7',0,1,2,1,1)
#pca1.eigen7('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',0,1,2,1,1,25,30)
#pca1.eigen7('230508_Carbopol_100weight_30frame_1','230509_CMC_100_weight_30frame_1','230509_PEO_100weight_30frame_1','230509_CMC1_Carbopol1_100weight_30frame_1','230508_PEO1_Carbopol1_100weight_30frame_1','230509_PEO1_CMC1_100weight_30frame_1','230509_PEO1_CMC1_Carbopol1_100weight_30frame_1',0,1,2,1,1,25,30)
#pca1.eigen7('230413_Carbopol_100weight','230411_CMC_100weight','230411_PEO_100weight','230412_CMC1_Carbopol1_100weight','230412_PEO1,Carbopol1_100weight','230412_PEO1,CMC1_100weight','230412_PEO1,CMC1,Carbopol1_100weight',0,1,2,1,1)
#pca1.eigen7('230410_Carbopol_weight','230411_CMC_weight','230411_PEO_weight','230412_CMC1_Carbopol1_weight','230412_PEO1,Carbopol1_weight','230412_PEO1,CMC1_weight','230412_PEO1,CMC1,Carbopol1_weight',0,1,2,1,1)
#pca1.eigen7('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',0,1,2,1,1)
#pca1.eigen7('230508_Carbopol_100weight_50frame','230509_CMC_100_weight_50frame','230509_PEO_100weight_50frame','230509_CMC1_Carbopol1_100weight_50frame','230508_PEO1_Carbopol1_100weight_50frame','230509_PEO1_CMC1_100weight_50frame','230509_PEO1_CMC1_Carbopol1_100weight_50frame',0,1,2,1,1,25,50)
#pca1.eigen7('230508_Carbopol_100weight_50frame_1','230509_CMC_100_weight_50frame_1','230509_PEO_100weight_50frame_1','230509_CMC1_Carbopol1_100weight_50frame_1','230508_PEO1_Carbopol1_100weight_50frame_1','230509_PEO1_CMC1_100weight_50frame_1','230509_PEO1_CMC1_Carbopol1_100weight_50frame_1',0,1,2,1,1,25,50)
#pca1.eigen7('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight')
#pca1.augmentation('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',3)
#pca1.augmentation('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',30)
#pca1.augmentation('230620_Carbopol_10frame_50weight','230620_CMC_10frame_50weight','230620_PEO_10frame_50weight','230620_Carbopol1_CMC1_10frame_50weight','230620_Carbopol1_PEO1_10frame_50weight','230620_PEO1_CMC1_10frame_50weight','230620_Carbopol1_CMC1_PEO1_10frame_50weight',30)
#pca1.component('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',30)
#pca1.box_Plot(55)


#pca1.accuracy_Plot('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',50)
#pca1.scatter_Plot(40)
#pca1.box_Plot2(30)
#pca1.ratio_Plot('220907_Carbopol_noweight','220907_CMC_noweight','220907_PEO_noweight','220907_CMC1,Carbopol1_noweight','220907_PEO1,Carbopol1_noweight','220907_PEO1,CMC1_noweight','220907_PEO1,CMC1,Carbopol1_noweight',0,1,2,1,1,5,50,7)
pca1.ratio_Plot('230621_Carbopol_10frame_150weight','230621_CMC_10frame_150weight','230621_PEO_10frame_150weight','230621_Carbopol1_CMC1_10frame_150weight','230621_Carbopol1_PEO1_10frame_150weight','230621_PEO1_CMC1_10frame_150weight','230621_Carbopol1_CMC1_PEO1_10frame_150weight',0,1,2,1,1,25,50,0)
#pca1.ratio_Plot('230508_Carbopol_100weight_30frame','230509_CMC_100_weight_30frame','230509_PEO_100weight_30frame','230509_CMC1_Carbopol1_100weight_30frame','230508_PEO1_Carbopol1_100weight_30frame','230509_PEO1_CMC1_100weight_30frame','230509_PEO1_CMC1_Carbopol1_100weight_30frame',0,1,2,1,1,25,50,10)
#pca1.ratio_Plot('230508_Carbopol_100weight_50frame','230509_CMC_100_weight_50frame','230509_PEO_100weight_50frame','230509_CMC1_Carbopol1_100weight_50frame','230508_PEO1_Carbopol1_100weight_50frame','230509_PEO1_CMC1_100weight_50frame','230509_PEO1_CMC1_Carbopol1_100weight_50frame',0,1,2,1,1,20,50,10)

#pca1.ratio_Plot('220907_Carbopol_noweight_1','220907_CMC_noweight_1','220907_PEO_noweight_1','220907_CMC1,Carbopol1_noweight_1','220907_PEO1,Carbopol1_noweight_1','220907_PEO1,CMC1_noweight_1','220907_PEO1,CMC1,Carbopol1_noweight_1',0,1,2,1,1,25,10,7)
#pca1.ratio_Plot('230413_Carbopol_100weight_1','230411_CMC_100weight_1','230411_PEO_100weight_1','230412_CMC1_Carbopol1_100weight_1','230412_PEO1,Carbopol1_100weight_1','230412_PEO1,CMC1_100weight_1','230412_PEO1,CMC1,Carbopol1_100weight_1',0,1,2,1,1,25,50,7)
#pca1.ratio_Plot('230508_Carbopol_100weight_30frame_1','230509_CMC_100_weight_30frame_1','230509_PEO_100weight_30frame_1','230509_CMC1_Carbopol1_100weight_30frame_1','230508_PEO1_Carbopol1_100weight_30frame_1','230509_PEO1_CMC1_100weight_30frame_1','230509_PEO1_CMC1_Carbopol1_100weight_30frame_1',0,1,2,1,1,25,50,29)
#pca1.ratio_Plot('230508_Carbopol_100weight_50frame_1','230509_CMC_100_weight_50frame_1','230509_PEO_100weight_50frame_1','230509_CMC1_Carbopol1_100weight_50frame_1','230508_PEO1_Carbopol1_100weight_50frame_1','230509_PEO1_CMC1_100weight_50frame_1','230509_PEO1_CMC1_Carbopol1_100weight_50frame_1',0,1,2,1,1,20,50,29)
# Out:
# images.shape: (210, 360, 400)
# 클래스의 개수: 7
